# %%
# !pip install fbprophet
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\Users\admin\anaconda3\envs\myenv\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-pzim9h6n\\fbprophet_c3707ff10f9a4f629e34ddc15587f3b2\\setup.py'"'"'; __file__='"'"'C:\\Users\\admin\\AppData\\Local\\Temp\\pip-install-pzim9h6n\\fbprophet_c3707ff10f9a4f629e34ddc15587f3b2\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\admin\AppData\Local\Temp\pip-wheel-juf_oqr0'
#        cwd: C:\Users\admin\AppData\Local\Temp\pip-install-pzim9h6n\fbprophet_c3707ff10f9a4f629e34ddc15587f3b2\
#   Complete output (40 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
# ...

# %%
from sktime.foraecasting import fbprophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16628/2578836885.py in <module>
# ----> 1 from sktime.forecasting import fbprophet
#
# ModuleNotFoundError: No module named 'sktime'
