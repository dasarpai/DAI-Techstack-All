# %% [markdown]
# ### Inspiration https://machinelearningmastery.com/2d-test-functions-for-function-optimization/
#
# #### https://en.wikipedia.org/wiki/Test_functions_for_optimization
# #Visulization

# %%
# unimodal test function
from numpy import arange
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
 
# objective function
def objective(x, y):
	return x**2.0 + y**2.0
 
# define range for input
r_min, r_max = -5.0, 5.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
# show the plot
pyplot.show()

# %%
# unimodal test function
from numpy import arange
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return 0.26 * (x**2 + y**2) - 0.48 * x * y

# define range for input
r_min, r_max = -10.0, 10.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
# show the plot
pyplot.show()

# %%
# unimodal test function
from numpy import cos
from numpy import exp
from numpy import pi
from numpy import arange
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return -cos(x) * cos(y) * exp(-((x - pi)**2 + (y - pi)**2))

# define range for input
r_min, r_max = -2, 2
# sample input range uniformly at 0.01 increments
xaxis = arange(r_min, r_max, 0.01)
yaxis = arange(r_min, r_max, 0.01)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
# show the plot
pyplot.show()

# %%
# multimodal test function
from numpy import arange
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import e
from numpy import pi
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return -20.0 * exp(-0.2 * sqrt(0.5 * (x**2 + y**2))) - exp(0.5 * (cos(2 * pi * x) + cos(2 * pi * y))) + e + 20

# define range for input
r_min, r_max = -5.0, 5.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
# show the plot
pyplot.show()

# %%
# multimodal test function
from numpy import arange
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return (x**2 + y - 11)**2 + (x + y**2 -7)**2

# define range for input
r_min, r_max = -5.0, 5.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
# show the plot
pyplot.show()

# %%
df=pd.DataFrame(results, columns=list(x)[0], index=list(y)[0])
df
# Out:
#           -5.0      -4.9      -4.8      -4.7      -4.6      -4.5      -4.4  \
# -5.0  250.0000  235.7701  223.8016  213.9781  206.1856  200.3125  196.2496
# -5.0  227.0501  212.4242  200.0637  189.8522  181.6757  175.4226  170.9837
# -5.0  206.5216  191.5037  178.7552  168.1597  159.6032  152.9741  148.1632
# -5.0  188.2981  172.8922  159.7597  148.7842  139.8517  132.8506  127.6717
# -5.0  172.2656  156.4757  142.9632  131.6117  122.3072  114.9381  109.3952
# ...        ...       ...       ...       ...       ...       ...       ...
# -5.0  410.3125  376.3226  344.9741  316.1506  289.7381  265.6250  243.7021
# -5.0  429.8656  395.8597  364.4992  335.6677  309.2512  285.1381  263.2192
# -5.0  451.4981  417.4802  386.1117  357.2762  330.8597  306.7506  284.8397
# -5.0  475.3216  441.2957  409.9232  381.0877  354.6752  330.5741  308.6752
# -5.0  501.4501  467.4202  436.0477  407.2162  380.8117  356.7226  334.8397
#
#           -4.3      -4.2      -4.1  ...       4.0       4.1       4.2  \
# -5.0  193.8901  193.1296  193.8661  ...  484.0000  489.0661  495.5296
# -5.0  168.2522  167.1237  167.4962  ...  441.4301  446.4602  452.8917
# -5.0  145.0637  143.5712  143.5837  ...  401.6416  406.6397  413.0432
# -5.0  124.2082  122.3557  122.0122  ...  364.5181  369.4882  375.8677
# -5.0  105.5717  103.3632  102.6677  ...  329.9456  334.8917  341.2512
# ...        ...       ...       ...  ...       ...       ...       ...
# -5.0  223.8626  206.0021  190.0186  ...  387.8125  407.3186  428.6021
# -5.0  243.3877  225.5392  209.5717  ...  421.9456  441.7957  463.4272
# -5.0  265.0202  247.1877  231.2402  ...  458.5181  478.7162  500.6997
# -5.0  288.8717  271.0592  255.1357  ...  497.6416  518.1917  540.5312
# -5.0  315.0562  297.2677  281.3722  ...  539.4301  560.3362  583.0357
#
#            4.3       4.4       4.5       4.6       4.7       4.8       4.9
# -5.0  503.4901  513.0496  524.3125  537.3856  552.3781  569.4016  588.5701
# -5.0  460.8242  470.3597  481.6026  494.6597  509.6402  526.6557  545.8202
# -5.0  420.9517  430.4672  441.6941  454.7392  469.7117  486.7232  505.8877
# -5.0  383.7562  393.2557  404.4706  417.5077  432.4762  449.4877  468.6562
# -5.0  349.1237  358.6112  369.8181  382.8512  397.8197  414.8352  434.0117
# ...        ...       ...       ...       ...       ...       ...       ...
# -5.0  451.7626  476.9021  504.1250  533.5381  565.2506  599.3741  636.0226
# -5.0  486.9397  512.4352  540.0181  569.7952  601.8757  636.3712  673.3957
# -5.0  524.5682  550.4237  578.3706  608.5157  640.9682  675.8397  713.2442
# -5.0  564.7597  590.9792  619.2941  649.8112  682.6397  717.8912  755.6797
# -5.0  607.6282  634.2157  662.9026  693.7957  727.0042  762.6397  800.8162
#
# [100 rows x 100 columns]

# %%
df.describe()
# Out:
#              -5.0        -4.9        -4.8        -4.7        -4.6        -4.5  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean   271.978330  244.614430  219.709930  197.148430  176.815930  158.600830
# std     93.319193   88.261813   83.422697   78.816930   74.461773   70.376775
# min    108.946100   89.671700   72.579200   57.687700   44.778100   33.625000
# 25%    189.953725  171.344075  151.378575  133.376075  120.895325  106.957025
# 50%    302.985600  269.865950  240.712650  214.184350  190.611450  170.318350
# 75%    337.217975  306.225500  277.715200  251.840200  229.579700  207.073225
# max    501.450100  467.420200  436.047700  407.216200  380.811700  356.722600
#
#              -4.4        -4.3        -4.2        -4.1  ...         4.0  \
# count  100.000000  100.000000  100.000000  100.000000  ...  100.000000
# mean   142.393930  128.088430  115.579930  104.766430  ...  116.908330
# std     66.583751   63.106544   59.970456   57.201226  ...  133.866483
# min     24.342100   16.795700   10.627200    6.019700  ...    9.982100
# 25%     94.712725   87.639475   78.399175   71.095075  ...   30.224975
# 50%    150.577450  133.795950  119.223450  105.415950  ...   47.642100
# 75%    189.923200  173.143700  159.161325  145.649800  ...  160.859375
# max    334.839700  315.056200  297.267700  281.372200  ...  539.430100
#
#               4.1         4.2         4.3         4.4         4.5         4.6  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean   126.660430  138.007930  151.050430  165.889930  182.630830  201.379930
# std    136.068886  138.434269  140.966179  143.667621  146.541075  149.588511
# min     15.726100   22.969600   31.830100   42.409600   54.770600   69.003700
# 25%     37.886075   45.795325   56.255425   68.811925   81.546875   97.342375
# 50%     58.987950   70.495450   84.562200  100.245450  117.016100  137.150650
# 75%    174.295475  183.937725  200.464825  218.952325  234.000475  256.883575
# max    560.336200  583.035700  607.628200  634.215700  662.902600  693.795700
#
#               4.7         4.8         4.9
# count  100.000000  100.000000  100.000000
# mean   222.246430  245.341930  270.780430
# std    152.811417  156.210830  159.787367
# min     85.272200  103.687700  124.363700
# 25%    115.713875  134.688575  156.428825
# 50%    157.560600  182.012650  207.077700
# 75%    281.342075  302.602325  332.587825
# max    727.004200  762.639700  800.816200
#
# [8 rows x 100 columns]

# %%
# multimodal test function
from numpy import arange
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import sin
from numpy import e
from numpy import pi
from numpy import absolute
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return -absolute(sin(x) * cos(y) * exp(absolute(1 - (sqrt(x**2 + y**2)/pi))))

# define range for input
r_min, r_max = -10.0, 10.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
# show the plot
pyplot.show()

# %%
# multimodal test function
from numpy import arange
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import sin
from numpy import e
from numpy import pi
from numpy import absolute
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return (x**2 + y -11)**2 + (x+ y**2 - 7)**2

# define range for input
r_min, r_max = -10.0, 10.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
# show the plot
pyplot.show()

# %%
# multimodal test function
from numpy import arange
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import sin
from numpy import e
from numpy import pi
from numpy import absolute
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return 2*x**2 - 1.05*x**4 + x**6/6 + x*y + y**2 

# define range for input
r_min, r_max = -10.0, 10.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
# show the plot
pyplot.show()

# %%
# multimodal test function
from numpy import arange
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import sin
from numpy import e
from numpy import pi
from numpy import absolute
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return (1-x)**2 + 100*(y-x**2)**2 

# define range for input
r_min, r_max = -10.0, 10.0
# sample input range uniformly at 0.1 increments
xaxis = arange(r_min, r_max, 0.1)
yaxis = arange(r_min, r_max, 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a surface plot with the jet color scheme
figure = pyplot.figure()
axis = figure.gca(projection='3d')
axis.plot_surface(x, y, results, cmap='jet')
# show the plot
pyplot.show()
